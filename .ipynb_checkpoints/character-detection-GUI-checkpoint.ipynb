# %%
from FinalModel import model
# Out:
# WARNING:tensorflow:From C:\ProgramData\Anaconda3\envs\py311\Lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.
#
# WARNING:tensorflow:From C:\ProgramData\Anaconda3\envs\py311\Lib\site-packages\keras\src\backend.py:1398: The name tf.executing_eagerly_outside_functions is deprecated. Please use tf.compat.v1.executing_eagerly_outside_functions instead.
#
# Model: "Mymodel"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  layer1 (Dense)              (None, 128)               10496
#
#  layer2 (Dense)              (None, 128)               16512
#
#  layer3 (Dense)              (None, 26)                3354
#
# =================================================================
# Total params: 30362 (118.60 KB)
# Trainable params: 30362 (118.60 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# w1 shape:(81, 128) , b1 shape: (128,)
# w2 shape:(128, 128) , b2 shape: (128,)
# w3 shape:(128, 26) , b3 shape: (26,)
# Epoch 1/100
# WARNING:tensorflow:From C:\ProgramData\Anaconda3\envs\py311\Lib\site-packages\keras\src\utils\tf_utils.py:492: The name tf.ragged.RaggedTensorValue is deprecated. Please use tf.compat.v1.ragged.RaggedTensorValue instead.
#
# WARNING:tensorflow:From C:\ProgramData\Anaconda3\envs\py311\Lib\site-packages\keras\src\engine\base_layer_utils.py:384: The name tf.executing_eagerly_outside_functions is deprecated. Please use tf.compat.v1.executing_eagerly_outside_functions instead.
#
# 2220/2220 [==============================] - 15s 5ms/step - loss: 0.9277 - accuracy: 0.7224
# Epoch 2/100
# 2220/2220 [==============================] - 12s 5ms/step - loss: 0.5517 - accuracy: 0.8220
# Epoch 3/100
# 2220/2220 [==============================] - 11s 5ms/step - loss: 0.4593 - accuracy: 0.8487
# Epoch 4/100
# 2220/2220 [==============================] - 11s 5ms/step - loss: 0.4067 - accuracy: 0.8653
# Epoch 5/100
# 2220/2220 [==============================] - 12s 6ms/step - loss: 0.3733 - accuracy: 0.8756
# Epoch 6/100
# 2220/2220 [==============================] - 12s 5ms/step - loss: 0.3499 - accuracy: 0.8820
# Epoch 7/100
# 2220/2220 [==============================] - 11s 5ms/step - loss: 0.3292 - accuracy: 0.8885
# Epoch 8/100
# 2220/2220 [==============================] - 11s 5ms/step - loss: 0.3130 - accuracy: 0.8945
# Epoch 9/100
# 2220/2220 [==============================] - 10s 4ms/step - loss: 0.2995 - accuracy: 0.8988
# Epoch 10/100
# 2220/2220 [==============================] - 10s 5ms/step - loss: 0.2867 - accuracy: 0.9016
# Epoch 11/100
# 2220/2220 [==============================] - 10s 4ms/step - loss: 0.2753 - accuracy: 0.9058
# Epoch 12/100
# 2220/2220 [==============================] - 19s 8ms/step - loss: 0.2665 - accuracy: 0.9086
# Epoch 13/100
# 2220/2220 [==============================] - 9s 4ms/step - loss: 0.2560 - accuracy: 0.9106
# Epoch 14/100
# 2220/2220 [==============================] - 11s 5ms/step - loss: 0.2490 - accuracy: 0.9138
# Epoch 15/100
# 2220/2220 [==============================] - 10s 5ms/step - loss: 0.2410 - accuracy: 0.9153
# Epoch 16/100
# 2220/2220 [==============================] - 10s 4ms/step - loss: 0.2337 - accuracy: 0.9184
# Epoch 17/100
# 2220/2220 [==============================] - 9s 4ms/step - loss: 0.2274 - accuracy: 0.9197
# Epoch 18/100
# 2220/2220 [==============================] - 9s 4ms/step - loss: 0.2203 - accuracy: 0.9225
# Epoch 19/100
# 2220/2220 [==============================] - 9s 4ms/step - loss: 0.2145 - accuracy: 0.9246
# Epoch 20/100
# 2220/2220 [==============================] - 8s 4ms/step - loss: 0.2090 - accuracy: 0.9260
# Epoch 21/100
# 2220/2220 [==============================] - 9s 4ms/step - loss: 0.2034 - accuracy: 0.9278
# Epoch 22/100
# 2220/2220 [==============================] - 11s 5ms/step - loss: 0.1981 - accuracy: 0.9290
# Epoch 23/100
# 2220/2220 [==============================] - 11s 5ms/step - loss: 0.1925 - accuracy: 0.9313
# Epoch 24/100
# 2220/2220 [==============================] - 11s 5ms/step - loss: 0.1881 - accuracy: 0.9312
# Epoch 25/100
# 2220/2220 [==============================] - 13s 6ms/step - loss: 0.1837 - accuracy: 0.9342
# Epoch 26/100
# 2220/2220 [==============================] - 9s 4ms/step - loss: 0.1784 - accuracy: 0.9356
# Epoch 27/100
# 2220/2220 [==============================] - 10s 4ms/step - loss: 0.1736 - accuracy: 0.9369
# Epoch 28/100
# 2220/2220 [==============================] - 11s 5ms/step - loss: 0.1695 - accuracy: 0.9382
# Epoch 29/100
# 2220/2220 [==============================] - 11s 5ms/step - loss: 0.1651 - accuracy: 0.9389
# Epoch 30/100
# 2220/2220 [==============================] - 11s 5ms/step - loss: 0.1613 - accuracy: 0.9411
# Epoch 31/100
# 2220/2220 [==============================] - 11s 5ms/step - loss: 0.1567 - accuracy: 0.9420
# Epoch 32/100
# 2220/2220 [==============================] - 11s 5ms/step - loss: 0.1529 - accuracy: 0.9433
# Epoch 33/100
# 2220/2220 [==============================] - 11s 5ms/step - loss: 0
100
# 2220/2220 [==============================] - 9s 4ms/step - loss: 0.0464 - accuracy: 0.9812
# Epoch 98/100
# 2220/2220 [==============================] - 9s 4ms/step - loss: 0.0470 - accuracy: 0.9811
# Epoch 99/100
# 2220/2220 [==============================] - 10s 4ms/step - loss: 0.0454 - accuracy: 0.9815
# Epoch 100/100
# 2220/2220 [==============================] - 10s 4ms/step - loss: 0.0446 - accuracy: 0.9816
# 555/555 [==============================] - 2s 3ms/step
# 555/555 [==============================] - 3s 4ms/step - loss: 0.8768 - accuracy: 0.8819

# %%
import customtkinter
import tkinter as tk
from tkinter import filedialog
import numpy as np

from PIL import Image
from skimage import feature,io,exposure
import tensorflow as tf

# %%
def MakePrediction(img):
    prediction=model.predict([img])
    prediction_p=tf.nn.softmax(prediction)
    
    return np.argmax(prediction_p)

# %%
def determine_letter(prediction):
    letters={i: chr(ord('a') + i) for i in range(26)}
    
    return letters[prediction]

# %%
def extract_feature(image):
    hog_image,_=feature.hog(image,visualize=True)
    return hog_image

# %%
def upload_file():
    file_path = filedialog.askopenfilename()
    # Process the uploaded file path or perform any desired actions
    if file_path:
        image=Image.open(file_path)
        
        image_array=np.asarray(image)
        
        
        image_array_2d= image_array[:,:,0].reshape((28,28))
        
        
        hog_image=extract_feature(image_array_2d)
        
        hog_image=hog_image.reshape((1,81))
        
        
        
        prediction=MakePrediction(hog_image)
        
        
        predicted_letter=determine_letter(prediction)
        
        print(predicted_letter)

# %%
app=customtkinter.CTk()

# %%
customtkinter.set_appearance_mode("dark")
customtkinter.set_default_color_theme("dark-blue")

# %%
screen_width=app.winfo_screenwidth()
screen_height=app.winfo_screenheight()

w=500
h=500

a=(screen_width/2)-(w/2)
b=(screen_height/2)-(h/2)


app.geometry("%dx%d+%d+%d" %(w,h,a,b))

# %%
app.title("OCR for HandWritten character")
# Out:
# ''

# %%
app.grid_columnconfigure(0,weight=1)
app.grid_rowconfigure(0,weight=1)

# %%
frame1=customtkinter.CTkFrame(app,width=300,height=300,fg_color="transparent")
frame1.grid(row=0,column=0,padx=10,pady=10)

# %%
label1=customtkinter.CTkLabel(frame1,text="Please choose a 28x28 image",fg_color="transparent",text_color="blue",font=("Arial",20))
label1.grid(row=0,column=0,padx=10,pady=10)

# %%
button1=customtkinter.CTkButton(frame1,text="Choose image",command=upload_file,corner_radius=15,fg_color="blue")
button1.grid(row=1,column=0,padx=10,pady=10)

# %%
app.mainloop()
# Out:
# 1/1 [==============================] - 0s 195ms/step
# q
# 1/1 [==============================] - 0s 207ms/step
# f
# 1/1 [==============================] - 0s 27ms/step
# y
# 1/1 [==============================] - 0s 25ms/step
# k
# 1/1 [==============================] - 0s 28ms/step
# n
# 1/1 [==============================] - 0s 24ms/step
# q
# 1/1 [==============================] - 0s 20ms/step
# y
# 1/1 [==============================] - 0s 29ms/step
# s
# 1/1 [==============================] - 0s 25ms/step
# a
# 1/1 [==============================] - 0s 19ms/step
# r
# 1/1 [==============================] - 0s 21ms/step
# a
# 1/1 [==============================] - 0s 30ms/step
# j
# 1/1 [==============================] - 0s 22ms/step
# b
# 1/1 [==============================] - 0s 30ms/step
# a
# 1/1 [==============================] - 0s 27ms/step
# j
